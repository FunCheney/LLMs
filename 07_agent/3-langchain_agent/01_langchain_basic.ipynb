# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain) (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain) (2.11.9)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.41)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.10.0)
# Requirement already satisfied: certifi in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/mico/PycharmProjects/LLMs/.venv/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

model_name = os.getenv("LOCAL_MODE")
print(model_name)
base_url = os.getenv("LOCAL_BASE_URL")
print(base_url)
# Out:
# None
# None

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(
    model=model_name,
    base_url=base_url,
    temperature=0.2
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_ollama import OllamaLLM
#       3 llm = OllamaLLM(
#       4     model=model_name,
#       5     base_url=base_url,
#       6     temperature=0.2
#       7 )
#
# ModuleNotFoundError: No module named 'langchain_ollama'

# %%
resp = llm.invoke("你好！用三句话介绍一下你能做什么。")
print(resp)
# Out:
# 😊 Ni Hao! I'm a large language model, capable of understanding and responding to human input in natural language. I can assist with tasks such as answering questions, generating text, translating languages, and even creating chatbot-like conversations. Whether you need help with research, writing, or just want to have a fun conversation, I'm here to help! 🤖

# %%
from langchain_core.messages import SystemMessage, HumanMessage
resp = llm.invoke([
    SystemMessage(content="你是一个智能助手"),
    HumanMessage(content="如何高效的学习大模型 Agent 开发")
])
print(resp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain_core.messages import SystemMessage, HumanMessage
#       2 resp = llm.invoke([
#       3     SystemMessage(content="你是一个智能助手"),
#       4     HumanMessage(content="如何高效的学习大模型 Agent 开发")
#       5 ])
#       6 print(resp)
#
# ModuleNotFoundError: No module named 'langchain_core'
